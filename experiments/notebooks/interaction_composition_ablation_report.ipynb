# %% [markdown]
# # Interaction-composition ablation report
#
# Numerical reports for the retained composition experiments.

# %%
import sys
sys.path.insert(0, "../..")

from experimenter.reporting import report_experiments
from experiments.plotting.interaction_composition_ablation import EXPERIMENTS, SPECS

# %% [markdown]
# ## MDGNC

# %%
experiments = EXPERIMENTS["mdgnc"]
specs = SPECS["mdgnc"]
report_experiments(
    paths=experiments.values(),
    labels=experiments,
    specs=specs,
    ncols=len(specs),
    band="p75",
    show_plot=True,
);
# Out:
#                      experiment               time             regret       HV gap ratio             spread
#           MG-LD-WLOA — additive     3463 +/- 217.3     63.2 +/- 10.83 0.2151 +/- 0.05144  1.046 +/- 0.08988
#     MG-LD-WLOA — multiplicative     3348 +/- 245.3    65.62 +/- 8.472 0.2235 +/- 0.04854    1.05 +/- 0.1155
# MG-LD-WLOA — additive + product     3525 +/- 292.7    64.25 +/- 7.157 0.2271 +/- 0.04219  1.102 +/- 0.09187
#               SP-RBF — additive     1622 +/- 92.46    76.57 +/- 13.51 0.3349 +/- 0.06988   1.084 +/- 0.1006
#         SP-RBF — multiplicative     1565 +/- 107.8     77.92 +/- 13.2 0.3243 +/- 0.05621  1.074 +/- 0.09652
#     SP-RBF — additive + product     1705 +/- 92.71    77.35 +/- 12.45 0.3197 +/- 0.07682   1.092 +/- 0.1113

# %% [markdown]
# ## Engine

# %%
experiments = EXPERIMENTS["engine"]
specs = SPECS["engine"]
report_experiments(
    paths=experiments.values(),
    labels=experiments,
    specs=specs,
    ncols=len(specs),
    band="p75",
    show_plot=True,
);
# Out:
#                      experiment               time             regret           gap ratio
#           MG-LD-WLOA — additive 1.916e+04 +/- 2486    81.86 +/- 54.22   0.1769 +/- 0.1801
#     MG-LD-WLOA — multiplicative 1.692e+04 +/- 2941    53.34 +/- 33.74 0.08189 +/- 0.07396
# MG-LD-WLOA — additive + product 1.975e+04 +/- 1628    54.81 +/- 28.74 0.08227 +/- 0.09989
#               SP-RBF — additive     9521 +/- 171.7    81.63 +/- 47.55   0.2021 +/- 0.1879
#         SP-RBF — multiplicative     8726 +/- 374.7     54.23 +/- 31.3 0.07917 +/- 0.06721
#     SP-RBF — additive + product     9202 +/- 449.5    53.28 +/- 30.32   0.1016 +/- 0.1032
