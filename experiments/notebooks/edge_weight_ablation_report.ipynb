# %% [markdown]
# # Edge-weight ablation report
#
# Numerical reports for the retained edge-weight experiments.

# %%
import sys
sys.path.insert(0, "../..")

from experimenter.reporting import report_experiments
from experiments.plotting.edge_weight_ablation import EXPERIMENTS, SPECS

# %% [markdown]
# ## MDGNC

# %%
experiments = EXPERIMENTS["mdgnc"]
report_experiments(
    paths=experiments.values(),
    labels=experiments,
    specs=SPECS,
    ncols=len(SPECS),
    band="p75",
    show_plot=True,
);
# Out:
#         experiment               time             regret       HV gap ratio             spread
#               HIER     1150 +/- 173.8    93.96 +/- 16.71 0.2395 +/- 0.06786  0.9732 +/- 0.1002
#            LD-WLOA     2539 +/- 169.6    68.75 +/- 12.71  0.2235 +/- 0.0664   1.078 +/- 0.1129

# %% [markdown]
# ## MDGNC-EF

# %%
experiments = EXPERIMENTS["mdgnc_edge_failures"]
report_experiments(
    paths=experiments.values(),
    labels=experiments,
    specs=SPECS,
    ncols=len(SPECS),
    band="p75",
    show_plot=True,
);
# Out:
#         experiment               time             regret       HV gap ratio             spread
#               HIER     1740 +/- 201.3    96.99 +/- 16.53 0.1573 +/- 0.09877  0.9975 +/- 0.0842
#            LD-WLOA     4041 +/- 348.5    115.1 +/- 31.06  0.3915 +/- 0.1483 0.8995 +/- 0.08108
#       LD-WLOA + EW     4053 +/- 620.6    51.41 +/- 17.89 0.0378 +/- 0.07766   1.069 +/- 0.1072
