# %% [markdown]
# # Final-method report
#
# Numerical reports for all retained methods. The publication figure is generated by `experiments.plotting.final_method`.

# %%
import sys
sys.path.insert(0, "../..")

from experimenter.reporting import report_experiments
from experiments.plotting.final_method import PROBLEMS

# %% [markdown]
# ## Engine

# %%
config = PROBLEMS["engine"]
report_experiments(
    paths=config["experiments"].values(),
    labels=config["experiments"],
    specs=config["specs"],
    ncols=len(config["specs"]),
    band="p75",
    show_plot=True,
);
# Out:
#         experiment               time             regret           gap ratio
#             Random   29.63 +/- 0.5169      191 +/- 39.71   0.6464 +/- 0.2807
#                 GA    34.74 +/- 1.194    148.9 +/- 52.59    0.3878 +/- 0.247
#               HIER     3286 +/- 522.7    81.62 +/- 48.08   0.2269 +/- 0.1864
#               KPLS     1550 +/- 217.4    67.51 +/- 47.25   0.1662 +/- 0.1709
#                BLR     329.4 +/- 32.3    40.21 +/- 24.17  0.09999 +/- 0.1007
#             SP-RBF     9276 +/- 391.2    47.91 +/- 24.09 0.08035 +/- 0.09944
#         MG-LD-WLOA 1.955e+04 +/- 1489    50.34 +/- 22.37 0.05964 +/- 0.06627
#           Arch2Vec     1159 +/- 131.9    96.62 +/- 63.57   0.2705 +/- 0.2785
#               DGBO     2062 +/- 225.9    99.39 +/- 68.11   0.3163 +/- 0.3227

# %% [markdown]
# ## MDGNC

# %%
config = PROBLEMS["mdgnc"]
report_experiments(
    paths=config["experiments"].values(),
    labels=config["experiments"],
    specs=config["specs"],
    ncols=len(config["specs"]),
    band="p75",
    show_plot=True,
);
# Out:
#         experiment               time          HV regret           HV ratio             spread
#             Random   4.307 +/- 0.1394      145 +/- 12.31 0.7831 +/- 0.08243  0.6834 +/- 0.1059
#                 GA   5.586 +/- 0.1986    140.7 +/- 11.67  0.6976 +/- 0.0822 0.7515 +/- 0.09531
#               HIER    974.4 +/- 182.8    92.39 +/- 17.67   0.256 +/- 0.1275  0.9913 +/- 0.1145
#               KPLS      332 +/- 23.85    84.64 +/- 12.25 0.2727 +/- 0.07497   1.016 +/- 0.1022
#                BLR    79.47 +/- 4.275    66.99 +/- 13.14 0.2713 +/- 0.06301   1.038 +/- 0.1339
#             SP-RBF     1700 +/- 93.85    77.27 +/- 13.31 0.3188 +/- 0.07234    1.07 +/- 0.1274
#         MG-LD-WLOA     3561 +/- 286.4    61.34 +/- 8.321 0.2176 +/- 0.04532  1.072 +/- 0.09784
#           Arch2Vec    467.5 +/- 46.42    85.31 +/- 16.69 0.3938 +/- 0.09014  1.032 +/- 0.09609
#               DGBO    735.5 +/- 127.8    65.89 +/- 15.76 0.2862 +/- 0.08338   1.064 +/- 0.1075

# %% [markdown]
# ## MDGNC-EF

# %%
config = PROBLEMS["mdgnc_edge_failures"]
report_experiments(
    paths=config["experiments"].values(),
    labels=config["experiments"],
    specs=config["specs"],
    ncols=len(config["specs"]),
    band="p75",
    show_plot=True,
);
# Out:
#         experiment               time          HV regret           HV ratio             spread
#             Random   6.886 +/- 0.1293    191.3 +/- 11.62 0.8103 +/- 0.05596 0.7095 +/- 0.09829
#                 GA   7.349 +/- 0.2906    178.9 +/- 11.03 0.6935 +/- 0.06412 0.6723 +/- 0.09349
#               HIER       1627 +/- 253    118.2 +/- 19.64  0.2837 +/- 0.1065   1.041 +/- 0.1388
#               KPLS    545.2 +/- 33.17    116.5 +/- 16.79 0.3189 +/- 0.07361  0.9718 +/- 0.1149
#                BLR    83.84 +/- 4.989    108.2 +/- 19.95 0.3534 +/- 0.08904  0.9774 +/- 0.1178
#             SP-RBF     3049 +/- 191.9    89.38 +/- 11.52 0.2795 +/- 0.06497   1.051 +/- 0.1086
#         MG-LD-WLOA     6373 +/- 492.4    64.95 +/- 11.76 0.1423 +/- 0.03885    1.039 +/- 0.103
#           Arch2Vec     630.6 +/- 43.5    119.5 +/- 23.01  0.4253 +/- 0.1011  0.9269 +/- 0.1027
#               DGBO     1120 +/- 256.7    73.49 +/- 16.61 0.2354 +/- 0.06618   1.076 +/- 0.1211

# %% [markdown]
# ## Rocket

# %%
config = PROBLEMS["rocket"]
report_experiments(
    paths=config["experiments"].values(),
    labels=config["experiments"],
    specs=config["specs"],
    ncols=len(config["specs"]),
    band="p75",
    show_plot=True,
);
# Out:
#         experiment                    time          HV regret           HV ratio             spread
#             Random         47.71 +/- 1.564    413.4 +/- 89.06  0.4925 +/- 0.1498  0.6593 +/- 0.1031
#                 GA          39.25 +/- 5.08    388.9 +/- 97.29   0.437 +/- 0.1381   0.8117 +/- 0.156
#               HIER      4.009e+04 +/- 6250    318.8 +/- 76.83  0.3694 +/- 0.1173 0.9074 +/- 0.08801
#               KPLS          4719 +/- 479.6    309.2 +/- 83.34  0.3672 +/- 0.1097  0.8475 +/- 0.1073
#                BLR         212.2 +/- 62.17    528.1 +/- 51.22 0.7389 +/- 0.09414  0.7769 +/- 0.1939
#             SP-RBF      3.759e+04 +/- 3812     401.1 +/- 86.9  0.4723 +/- 0.1556   1.133 +/- 0.1076
#         MG-LD-WLOA 1.395e+05 +/- 2.737e+04     352.6 +/- 83.5   0.4209 +/- 0.131    1.04 +/- 0.1293
#           Arch2Vec          1256 +/- 358.9    531.7 +/- 54.61  0.7283 +/- 0.1079   0.784 +/- 0.2785
# ...
