# %% [markdown]
# # Encoding-granularity ablation report
#
# Numerical reports for the retained granularity experiments.

# %%
import sys
sys.path.insert(0, "../..")

from experimenter.reporting import report_experiments
from experiments.plotting.encoding_granularity_ablation import EXPERIMENTS, SPECS

# %% [markdown]
# ## Engine

# %%
experiments = EXPERIMENTS["engine"]
specs = SPECS["engine"]
report_experiments(
    paths=experiments.values(),
    labels=experiments,
    specs=specs,
    ncols=len(specs),
    band="p75",
    show_plot=True,
);
# Out:
#           experiment                time             regret           gap ratio
#                  DSG  1.35e+04 +/- 672.1     48.7 +/- 27.16  0.08155 +/- 0.1061
#                 ADSG 1.385e+04 +/- 668.6     52.6 +/- 30.31  0.08986 +/- 0.1099
#        Semantic type 1.459e+04 +/- 668.6    52.34 +/- 24.85 0.07943 +/- 0.07639
# ADSG + semantic type  1.975e+04 +/- 1628    54.81 +/- 28.74 0.08227 +/- 0.09989

# %% [markdown]
# ## MDGNC

# %%
experiments = EXPERIMENTS["mdgnc"]
specs = SPECS["mdgnc"]
report_experiments(
    paths=experiments.values(),
    labels=experiments,
    specs=specs,
    ncols=len(specs),
    band="p75",
    show_plot=True,
);
# Out:
#           experiment               time             regret       HV gap ratio             spread
#                  DSG     2688 +/- 148.2     62.25 +/- 8.44 0.2184 +/- 0.05718   1.04 +/- 0.07952
#                 ADSG     2656 +/- 100.5    68.53 +/- 10.15 0.2413 +/- 0.06621   1.096 +/- 0.1185
#        Semantic type     2767 +/- 138.4     67.61 +/- 8.39 0.2142 +/- 0.04248   1.079 +/- 0.1063
# ADSG + semantic type     3525 +/- 292.7    64.25 +/- 7.157 0.2271 +/- 0.04219  1.102 +/- 0.09187
