# %% [markdown]
# # WLOA-depth ablation report
#
# Numerical reports for fixed depths 0–8 and learned LD-WLOA depth.

# %%
import sys
sys.path.insert(0, "../..")

from experimenter.reporting import report_experiments
from experiments.plotting.wloa_depth_ablation import EXPERIMENTS, SETTINGS

# %% [markdown]
# ## Engine

# %%
experiments = EXPERIMENTS["engine"]
config = SETTINGS["engine"]
specs = [("regret", config["regret"], False), ("ratio", config["ratio"], False), ("time", "runtime_sec", False)]
report_experiments(
    paths=experiments.values(),
    labels=experiments,
    specs=specs,
    ncols=len(specs),
    band="p75",
    show_plot=True,
);
# Out:
#         experiment             regret               ratio                time
#          Fixed d=0    57.26 +/- 32.96 0.08767 +/- 0.08369      7025 +/- 639.4
#          Fixed d=1    51.07 +/- 28.54 0.08687 +/- 0.09505      7855 +/- 700.9
#          Fixed d=2     45.6 +/- 27.35  0.0694 +/- 0.09028       7008 +/- 1273
#          Fixed d=3     56.3 +/- 36.05   0.1141 +/- 0.1281      8373 +/- 418.2
#          Fixed d=4    62.18 +/- 39.81   0.1281 +/- 0.1446      8922 +/- 510.9
#          Fixed d=5    50.49 +/- 27.57  0.0763 +/- 0.08395        9598 +/- 619
#          Fixed d=6    54.59 +/- 31.72  0.09005 +/- 0.1149 1.019e+04 +/- 937.8
#          Fixed d=7    49.48 +/- 30.62  0.09026 +/- 0.1105 1.066e+04 +/- 761.8
#          Fixed d=8    49.18 +/- 29.25 0.07061 +/- 0.08441 1.134e+04 +/- 877.2
#            LD-WLOA    52.34 +/- 24.85 0.07943 +/- 0.07639 1.459e+04 +/- 668.6

# %% [markdown]
# ## MDGNC

# %%
experiments = EXPERIMENTS["mdgnc"]
config = SETTINGS["mdgnc"]
specs = [("regret", config["regret"], False), ("ratio", config["ratio"], False), ("time", "runtime_sec", False)]
report_experiments(
    paths=experiments.values(),
    labels=experiments,
    specs=specs,
    ncols=len(specs),
    band="p75",
    show_plot=True,
);
# Out:
#         experiment             regret              ratio               time
#          Fixed d=0    111.5 +/- 15.06   0.5155 +/- 0.114     1288 +/- 130.9
#          Fixed d=1    88.97 +/- 13.56 0.3624 +/- 0.07791     1363 +/- 158.6
#          Fixed d=2    78.11 +/- 13.23 0.2788 +/- 0.06825     1455 +/- 115.3
#          Fixed d=3    66.04 +/- 8.379 0.2105 +/- 0.03821       1497 +/- 107
#          Fixed d=4    65.02 +/- 7.491 0.2054 +/- 0.02683     1471 +/- 107.2
#          Fixed d=5    64.57 +/- 6.342 0.2029 +/- 0.03173     1646 +/- 86.14
#          Fixed d=6    66.92 +/- 6.913 0.1881 +/- 0.02511     1682 +/- 108.1
#          Fixed d=7    67.75 +/- 10.28 0.1963 +/- 0.03698     1764 +/- 124.5
#          Fixed d=8    68.53 +/- 7.308 0.1857 +/- 0.03511     1859 +/- 116.7
#            LD-WLOA     67.61 +/- 8.39 0.2142 +/- 0.04248     2767 +/- 138.4
